# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from collection import Collection

# %%
try:
    collection
except NameError:
    collection = Collection()

# %%
collection.import_file('dbs/mai/all/auto.json', force=True)

# %%
df = collection.df_row_per_algorithm()
df
# Out:
#      acc_max  acc_mean  acc_median  acc_min  acc_quantile_25  acc_quantile_75  \
# 0      82.33   74.3483      74.420    65.12          72.5600          76.3950
# 1      79.07   67.9074      68.370    58.60          65.0025          70.7000
# 2      82.33   74.5571      74.420    64.65          72.5600          76.7400
# 3      83.72   74.6179      74.650    66.05          72.5600          76.7400
# 4      80.00   68.3309      68.605    59.53          65.9325          70.7000
# 5      82.33   75.1806      75.350    66.05          73.0200          77.6700
# 6      83.72   76.2967      76.280    67.44          73.9500          78.7175
# 7      77.21   68.4423      68.840    59.53          66.5100          70.7000
# 8      83.72   76.0454      75.810    68.37          73.9500          78.6000
# 9      82.79   76.3762      76.045    66.05          74.4200          79.0700
# 10     78.60   67.3072      67.910    53.02          64.0725          69.8850
# ...
