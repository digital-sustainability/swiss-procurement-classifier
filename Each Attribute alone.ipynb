# %% [markdown]
# # Each Attribute alone
#
# A run where each attribute is tried separately

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from collection import Collection

# %%
try:
    collection
except NameError:
    collection = Collection()

# %%
collection.import_file('dbs/mai/each-attributes-alone/auto.json', force=True)

# %%
df = collection.df_row_per_algorithm()
df = df[df['algorithm']=='decision_tree']
df
# Out:
#      acc_max  acc_mean  acc_median  acc_min  acc_quantile_25  acc_quantile_75  \
# 1      75.81   68.1451      68.840    60.47          65.1200          71.1600
# 4      73.95   68.2518      68.370    60.93          66.0500          70.2300
# 7      67.91   61.2334      60.930    53.49          59.5300          63.7200
# 10     65.58   59.7068      59.765    51.63          57.6700          61.8600
# 13     72.09   65.9823      66.050    58.60          63.7200          67.9100
# 16     65.58   59.7068      59.765    51.63          57.6700          61.8600
# 19     65.58   59.3719      59.070    51.63          57.2100          61.0475
# 22     67.91   60.7676      60.930    52.56          59.0700          62.7900
# 25     94.56   80.6045      80.950    67.35          76.8700          83.8400
# 28     85.03   77.6384      78.230    68.03          75.3400          80.2700
# 31     74.15   63.6671      62.930    53.74          61.2200          66.6700
# ...

# %%
df['attribute'] = [a['attributes'][0] for a in collection.list]
df['mcc_mean'] = df['mcc_mean'] * 100

# %%
df.groupby(['attribute']).mean()
#.plot.bar(y=['acc_mean'])
# Out:
#                           acc_max   acc_mean  acc_median    acc_min  \
# attribute
# auftragsart_art         90.946429  76.246529   76.792143  53.755714
# ausschreibung_cpv       95.152000  76.714093   78.497000  40.718667
# beschaffungsstelle_plz  88.946429  65.989971   67.211429  35.058571
# gatt_wto                77.355000  57.969513   59.102187  30.802500
# lose                    82.543333  62.630993   63.506667  35.738667
# sprache                 79.478125  56.929862   58.067500  31.334375
# teilangebote            82.426667  61.669993   63.274667  34.662000
# varianten               77.603125  56.439538   57.423750  32.637500
#
#                         acc_quantile_25  acc_quantile_75    acc_std  \
# attribute
# auftragsart_art               71.600000        82.698571   8.155568
# ausschreibung_cpv             69.213833        86.748000  12.458521
# beschaffungsstelle_plz        59.901607        74.386429  11.672561
# ...

# %%
ax = df.groupby(['attribute']).mean().plot.bar(y=['acc_mean','mcc_mean'], figsize=(12,8), fontsize=14)
ax.set_title("Decision Tree", fontsize=16)
# Out:
# Text(0.5, 1.0, 'Decision Tree')
